# %%
import numpy as np
import h5py

# %%
h5 = h5py.File("/Users/yoachim/rubin_sim_data/skybrightness_pre/60841_61054.h5")

# %%
mjds = h5["mjds"][:]

# %%
mjds
# Out:
# array([60841.        , 60841.00347222, 60841.01041667, ...,
#        61053.35416647, 61053.36458314, 61053.37152758], shape=(9256,))
