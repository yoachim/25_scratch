# %%
import numpy as np
import matplotlib.pylab as plt
#from rubin_scheduler.scheduler.example import generate_baseline_coresched
# %matplotlib inline
from example_scheduler_qm import run_sched, generate_baseline_coresched
import rubin_sim.maf_proto as maf
import healpy as hp

# %%
qm_scheduler = generate_baseline_coresched()
observatory, qm_scheduler, qm_observations = run_sched(qm_scheduler, survey_length=10, verbose=True)

qm_observations["az"] = np.degrees(qm_observations["az"])
qm_observations["alt"] = np.degrees(qm_observations["alt"])
# Out:
# /Users/yoachim/anaconda3/envs/rubin13/lib/python3.13/site-packages/erfa/core.py:133: ErfaWarning: ERFA function "utctai" yielded 463 of "dubious year (Note 3)"
#   warn(f'ERFA function "{func_name}" yielded {wmsg}', ErfaWarning)
# /Users/yoachim/anaconda3/envs/rubin13/lib/python3.13/site-packages/erfa/core.py:133: ErfaWarning: ERFA function "taiutc" yielded 463 of "dubious year (Note 4)"
#   warn(f'ERFA function "{func_name}" yielded {wmsg}', ErfaWarning)
# /Users/yoachim/anaconda3/envs/rubin13/lib/python3.13/site-packages/erfa/core.py:133: ErfaWarning: ERFA function "utctai" yielded 162 of "dubious year (Note 3)"
#   warn(f'ERFA function "{func_name}" yielded {wmsg}', ErfaWarning)
# /Users/yoachim/anaconda3/envs/rubin13/lib/python3.13/site-packages/erfa/core.py:133: ErfaWarning: ERFA function "taiutc" yielded 162 of "dubious year (Note 4)"
#   warn(f'ERFA function "{func_name}" yielded {wmsg}', ErfaWarning)
# /Users/yoachim/git_repos/rubin_scheduler/rubin_scheduler/utils/healpy_utils.py:342: UserWarning: Can not connect to any more pixels.
#   warnings.warn("Can not connect to any more pixels.")
# progress = 1.25%
# /Users/yoachim/git_repos/rubin_scheduler/rubin_scheduler/scheduler/schedulers/core_scheduler.py:338: UserWarning: Looks like the queue manager rejected everything from a survey.
#   warnings.warn("Looks like the queue manager rejected everything from a survey.")
# /Users/yoachim/git_repos/rubin_scheduler/rubin_scheduler/scheduler/sim_runner.py:166: UserWarning: No observation. Step into the future and trying again.
#   warnings.warn("No observation. Step into the future and trying again.")
# progress = 19.58%
# /Users/yoachim/git_repos/rubin_scheduler/rubin_scheduler/skybrightness_pre/sky_model_pre.py:401: UserWarning: Requested MJD between sunrise and sunset, returning closest maps
#   warnings.warn("Requested MJD between sunrise and sunset, returning closest maps")
# progress = 20.00%
# /Users/yoachim/git_repos/rubin_scheduler/rubin_scheduler/utils/healpy_utils.py:342: UserWarning: Can not connect to any more pixels.
#   warnings.warn("Can not connect to any more pixels.")
# progress = 20.84%
# /Users/yoachim/git_repos/rubin_scheduler/rubin_scheduler/scheduler/schedulers/core_scheduler.py:338: UserWarning: Looks like the queue manager rejected everything from a survey.
#   warnings.warn("Looks like the queue manager rejected everything from a survey.")
# /Users/yoachim/git_repos/rubin_scheduler/rubin_scheduler/scheduler/sim_runner.py:166: UserWarning: No observation. Step into the future and trying again.
#   warnings.warn("No observation. Step into the future and trying again.")
# progress = 41.76%
# /Users/yoachim/git_repos/rubin_scheduler/rubin_scheduler/scheduler/features/features.py:530: UserWarning: Time must flow forwards to track the feature in NObservationsCurrentSeason.Not updating season_map.
#   warnings.warn(
# progress = 99.96%Skipped 42 observations
# Flushed 0 observations from queue for being stale
# Completed 7721 observations
# ran in 3 min = 0.1 hours

# %%
from example_scheduler import run_sched, generate_baseline_coresched

# %%
scheduler = generate_baseline_coresched()
observatory, scheduler, observations = run_sched(scheduler, survey_length=10, verbose=True)

observations["az"] = np.degrees(observations["az"])
observations["alt"] = np.degrees(observations["alt"])
# Out:
# /Users/yoachim/anaconda3/envs/rubin13/lib/python3.13/site-packages/erfa/core.py:133: ErfaWarning: ERFA function "utctai" yielded 463 of "dubious year (Note 3)"
#   warn(f'ERFA function "{func_name}" yielded {wmsg}', ErfaWarning)
# /Users/yoachim/anaconda3/envs/rubin13/lib/python3.13/site-packages/erfa/core.py:133: ErfaWarning: ERFA function "taiutc" yielded 463 of "dubious year (Note 4)"
#   warn(f'ERFA function "{func_name}" yielded {wmsg}', ErfaWarning)
# /Users/yoachim/anaconda3/envs/rubin13/lib/python3.13/site-packages/erfa/core.py:133: ErfaWarning: ERFA function "utctai" yielded 162 of "dubious year (Note 3)"
#   warn(f'ERFA function "{func_name}" yielded {wmsg}', ErfaWarning)
# /Users/yoachim/anaconda3/envs/rubin13/lib/python3.13/site-packages/erfa/core.py:133: ErfaWarning: ERFA function "taiutc" yielded 162 of "dubious year (Note 4)"
#   warn(f'ERFA function "{func_name}" yielded {wmsg}', ErfaWarning)
# /Users/yoachim/git_repos/rubin_scheduler/rubin_scheduler/utils/healpy_utils.py:342: UserWarning: Can not connect to any more pixels.
#   warnings.warn("Can not connect to any more pixels.")
# progress = 19.58%
# /Users/yoachim/git_repos/rubin_scheduler/rubin_scheduler/skybrightness_pre/sky_model_pre.py:401: UserWarning: Requested MJD between sunrise and sunset, returning closest maps
#   warnings.warn("Requested MJD between sunrise and sunset, returning closest maps")
# progress = 61.23%
# /Users/yoachim/git_repos/rubin_scheduler/rubin_scheduler/scheduler/features/features.py:530: UserWarning: Time must flow forwards to track the feature in NObservationsCurrentSeason.Not updating season_map.
#   warnings.warn(
# progress = 99.96%Skipped 0 observations
# Flushed 0 observations from queue for being stale
# Completed 9138 observations
# ran in 3 min = 0.1 hours

# %%
#fig, ax = plt.subplots()
#ax.plot(observations["az"], observations["alt"], 'ko')

# %%
sl = maf.Slicer(lon_col="az", lat_col="alt", nside=64)
metric = maf.CountMetric()
hp_array = sl(observations, metric)

pl = maf.PlotLambert()
fig = pl(hp_array, title="No Queue Manager")

# %%
#plt.plot(qm_observations["az"], qm_observations["alt"], 'ko')

# %%
sl = maf.Slicer(lon_col="az", lat_col="alt", nside=64)
metric = maf.CountMetric()
hp_array = sl(qm_observations, metric)

pl = maf.PlotLambert()
fig = pl(hp_array, title="With Queue Manager", label="Count")
# Out:
# /Users/yoachim/git_repos/rubin_sim/rubin_sim/maf_proto/plots/plots.py:564: UserWarning: The following kwargs were not used by contour: 'label'
#   tcf = ax.tricontourf(
