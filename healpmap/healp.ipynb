# %%
import numpy as np
import healpy as hp
import matplotlib.pylab as plt
# %matplotlib inline

# %%
ack = np.random.rand(hp.nside2npix(128))

# %%
hp.mollview(ack)

# %%
mask = ack*0
mask[np.where(ack > 0.1)] = 1
hp.mollview(mask)

# %%
hp.mollview(hp.ud_grade(mask, 32))

# %%
mask = ack*0
mask[0:20000] =1
hp.mollview(mask)

# %%
hp.mollview(hp.ud_grade(mask, 32))
